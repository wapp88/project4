# %%
# !pip install mrjob==0.6.12

# %%
import mrjob

# %%
# !python UserIdCounter.py movie_rating.txt > useridcounter.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /tmp/UserIdCounter.root.20230614.124708.990493
# Running step 1 of 1...
# job output is in /tmp/UserIdCounter.root.20230614.124708.990493/output
# Streaming final output from /tmp/UserIdCounter.root.20230614.124708.990493/output...
# Removing temp directory /tmp/UserIdCounter.root.20230614.124708.990493...

# %%
# !python RatingCounter.py movie_rating.txt > ratingcounter.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /tmp/RatingCounter.root.20230614.124733.349410
# Running step 1 of 1...
# job output is in /tmp/RatingCounter.root.20230614.124733.349410/output
# Streaming final output from /tmp/RatingCounter.root.20230614.124733.349410/output...
# Removing temp directory /tmp/RatingCounter.root.20230614.124733.349410...
